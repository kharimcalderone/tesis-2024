# %%
import tensorflow as tf

#config = tf.ConfigProto()
#config.gpu_options.allow_growth = True
#sess = tf.Session(config=config)
import os
os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = "true"




import string
import re
from numpy import array, argmax, random, take
import pandas as pd
#from keras.models import Sequential                                     tf.keras.Sequential
#from keras.layers import Dense, LSTM, Embedding, RepeatVector           tf.keras.layers
#from keras.preprocessing.text import Tokenizer                          tf.keras.preprocessing.text.Tokenizer
#from keras.callbacks import ModelCheckpoint                             tf.keras.callbacks.ModelCheckpoint
#from keras.preprocessing.sequence import pad_sequences                  tf.keras.preprocessing.sequence.pad_sequences
#from keras.models import load_model                                     tf.keras.models.load_model
#from keras import optimizers                                            tf.keras.optimizers  
import matplotlib.pyplot as plt
import os

# %matplotlib inline
pd.set_option('display.max_colwidth', 200)
# Out:
# C:\Users\karim\anaconda3\envs\tesis\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\karim\anaconda3\envs\tesis\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\karim\anaconda3\envs\tesis\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\karim\anaconda3\envs\tesis\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\karim\anaconda3\envs\tesis\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\karim\anaconda3\envs\tesis\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Users\karim\anaconda3\envs\tesis\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\karim\anaconda3\envs\tesis\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\karim\anaconda3\envs\tesis\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\karim\anaconda3\envs\tesis\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\karim\anaconda3\envs\tesis\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\karim\anaconda3\envs\tesis\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
# function to read raw text file
def read_text(filename):
        # open the file
        file = open(filename, mode='rt', encoding='utf-8')
        
        # read all text
        text = file.read()
        file.close()
        return text

# %%
# split a text into sentences
def to_lines(text):
      sents = text.strip().split('\n')
      sents = [i.split('\t') for i in sents]
      return sents

# %%
data = read_text("esp_pur.txt")
beng_eng = to_lines(data)
beng_eng = array(beng_eng)

# %%
beng_eng = beng_eng[:50000,:]

# %%
beng_eng
# Out:
# array([['hola', 'hello'],
#        ['mundo', 'world'],
#        ['aqui', 'here'],
#        ['bien', 'well'],
#        ['correr', 'run'],
#        ['nadar', 'swim']], dtype='<U6')

# %%
# Remove punctuation
beng_eng[:,0] = [s.translate(str.maketrans('', '', string.punctuation)) for s in beng_eng[:,0]]
beng_eng[:,1] = [s.translate(str.maketrans('', '', string.punctuation)) for s in beng_eng[:,1]]

beng_eng
# Out:
# array([['hola', 'hello'],
#        ['mundo', 'world'],
#        ['aqui', 'here'],
#        ['bien', 'well'],
#        ['correr', 'run'],
#        ['nadar', 'swim']], dtype='<U6')

# %%
# convert text to lowercase
for i in range(len(beng_eng)):
    beng_eng[i,0] = beng_eng[i,0].lower()
    beng_eng[i,1] = beng_eng[i,1].lower()

beng_eng[0,1]
# Out:
# 'hello'

# %%
# empty lists
eng_l = []
ben_l = []

# populate the lists with sentence lengths
for i in beng_eng[:,0]:
      eng_l.append(len(i.split()))

for i in beng_eng[:,1]:
      ben_l.append(len(i.split()))

# %%
# function to build a tokenizer
def tokenization(lines):
      tokenizer = tf.keras.preprocessing.text.Tokenizer()
      tokenizer.fit_on_texts(lines)
      return tokenizer

# %%
# prepare english tokenizer
eng_tokenizer = tokenization(beng_eng[:, 0])
eng_vocab_size = len(eng_tokenizer.word_index) + 1

eng_length = 8
print('English Vocabulary Size: %d' % eng_vocab_size)
#import io,json
#tok_jsn = eng_tokenizer.to_json()
#with io.open('eng_tokn.json','w',encoding='utf-8') as f:
#    f.write(json.dumps(tok_jsn,ensure_ascii=False))

import json 
with open( 'word_dict1.json' , 'w' ) as file:    
    json.dump( eng_tokenizer.index_word , file )
# Out:
# English Vocabulary Size: 7

# %%
# prepare Deutch tokenizer
deu_tokenizer = tokenization(beng_eng[:, 1])
deu_vocab_size = len(deu_tokenizer.word_index) + 1

ben_length = 8
print('Deutch Vocabulary Size: %d' % deu_vocab_size)

import json 
with open( 'word_dict.json' , 'w' ,encoding='utf8') as file:    
    json.dump( deu_tokenizer.index_word , file, ensure_ascii=False )
# Out:
# Deutch Vocabulary Size: 7

# %%
# encode and pad sequences
def encode_sequences(tokenizer, length, lines):
         # integer encode sequences
         seq = tokenizer.texts_to_sequences(lines)
         # pad sequences with 0 values
         seq = tf.keras.preprocessing.sequence.pad_sequences(seq, maxlen=length, padding='post')
         return seq

# %%
from sklearn.model_selection import train_test_split

# split data into train and test set
train, test = train_test_split(beng_eng, test_size=0.2, random_state = 12)

# %%
# prepare training data
trainY = encode_sequences(deu_tokenizer, ben_length, train[:, 1])
trainX = encode_sequences(eng_tokenizer, eng_length, train[:, 0])

# prepare validation data
testY = encode_sequences(deu_tokenizer, ben_length, test[:, 1])
testX = encode_sequences(eng_tokenizer, eng_length, test[:, 0])

# %%
# build NMT model
def define_model(in_vocab,out_vocab, in_timesteps,out_timesteps,units):
      model = tf.keras.Sequential()
      model.add(tf.keras.layers.Embedding(in_vocab, units, input_length=in_timesteps, mask_zero=True))
      model.add(tf.keras.layers.LSTM(units))
      model.add(tf.keras.layers.RepeatVector(out_timesteps))
      model.add(tf.keras.layers.LSTM(units, return_sequences=True))
      model.add(tf.keras.layers.Dense(out_vocab, activation='softmax'))
      return model

# %%
# model compilation
model = define_model( eng_vocab_size,deu_vocab_size, eng_length,ben_length, 512)
model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\karim\anaconda3\envs\tesis\lib\site-packages\tensorflow\python\keras\initializers.py:119: calling RandomUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\Users\karim\anaconda3\envs\tesis\lib\site-packages\tensorflow\python\ops\init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\Users\karim\anaconda3\envs\tesis\lib\site-packages\tensorflow\python\keras\backend.py:3794: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 8, 512)            3584
# _________________________________________________________________
# lstm (LSTM)                  (None, 512)               2099200
# _________________________________________________________________
# repeat_vector (RepeatVector) (None, 8, 512)            0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 8, 512)            2099200
# _________________________________________________________________
# dense (Dense)                (None, 8, 7)              3591
# =================================================================
# Total params: 4,205,575
# Trainable params: 4,205,575
# Non-trainable params: 0
# _________________________________________________________________

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))

gpus = tf.config.experimental.list_logical_devices('GPU')
# Out:
# Num GPUs Available:  0

# %%
rms = tf.keras.optimizers.RMSprop(lr=0.001)
model.compile(optimizer=rms, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
# train model


# filename = 'model_05_12_2019_v2.h5'
# filename2 = 'model_05_12_2019_v1_OUT_1_Beng'
filename = 'model.h1.24_jan_19'
checkpoint = tf.keras.callbacks.ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='min')

model = tf.keras.models.load_model(filename)

history = model.fit(trainX, trainY.reshape(trainY.shape[0], trainY.shape[1], 1), 
          epochs=100, batch_size=128, 
          validation_split = 0.1,
          callbacks=[checkpoint], verbose=1)

model.save(filename)
model.save(filename2)
# Out:
# Train on 3 samples, validate on 1 samples
# Epoch 1/100
#
# Epoch 00001: val_loss improved from inf to 1.05699, saving model to model.h1.24_jan_19
# 3/3 [==============================] - 2s 816ms/sample - loss: 0.1722 - val_loss: 1.0570
# Epoch 2/100
#
# Epoch 00002: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 180ms/sample - loss: 0.1498 - val_loss: 1.0587
# Epoch 3/100
#
# Epoch 00003: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 231ms/sample - loss: 0.1247 - val_loss: 1.0613
# Epoch 4/100
#
# Epoch 00004: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 170ms/sample - loss: 0.0983 - val_loss: 1.0647
# Epoch 5/100
#
# Epoch 00005: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 178ms/sample - loss: 0.0728 - val_loss: 1.0689
# Epoch 6/100
#
# Epoch 00006: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 178ms/sample - loss: 0.0510 - val_loss: 1.0734
# Epoch 7/100
#
# Epoch 00007: val_loss did not improve from 1.05699
# 3/3 [==============================] - 0s 162ms/sample - loss: 0.0345 - val_loss: 1.0777
# Epoch 8/100
#
# Epoch 00008: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 177ms/sample - loss: 0.0233 - val_loss: 1.0817
# Epoch 9/100
#
# Epoch 00009: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 173ms/sample - loss: 0.0161 - val_loss: 1.0850
# Epoch 10/100
#
# Epoch 00010: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 172ms/sample - loss: 0.0115 - val_loss: 1.0879
# Epoch 11/100
#
# Epoch 00011: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 168ms/sample - loss: 0.0085 - val_loss: 1.0903
# Epoch 12/100
#
# Epoch 00012: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 174ms/sample - loss: 0.0065 - val_loss: 1.0924
# Epoch 13/100
#
# Epoch 00013: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 186ms/sample - loss: 0.0050 - val_loss: 1.0943
# Epoch 14/100
#
# Epoch 00014: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 168ms/sample - loss: 0.0040 - val_loss: 1.0959
# Epoch 15/100
#
# Epoch 00015: val_loss did not improve from 1.05699
# 3/3 [==============================] - 0s 166ms/sample - loss: 0.0033 - val_loss: 1.0974
# Epoch 16/100
#
# Epoch 00016: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 174ms/sample - loss: 0.0027 - val_loss: 1.0988
# Epoch 17/100
#
# Epoch 00017: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 182ms/sample - loss: 0.0023 - val_loss: 1.1001
# Epoch 18/100
#
# Epoch 00018: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 173ms/sample - loss: 0.0019 - val_loss: 1.1012
# Epoch 19/100
#
# Epoch 00019: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 172ms/sample - loss: 0.0017 - val_loss: 1.1023
# Epoch 20/100
#
# Epoch 00020: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 167ms/sample - loss: 0.0014 - val_loss: 1.1034
# Epoch 21/100
#
# Epoch 00021: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 172ms/sample - loss: 0.0012 - val_loss: 1.1043
# Epoch 22/100
#
# Epoch 00022: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 167ms/sample - loss: 0.0011 - val_loss: 1.1053
# Epoch 23/100
#
# Epoch 00023: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 173ms/sample - loss: 9.6281e-04 - val_loss: 1.1062
# Epoch 24/100
#
# Epoch 00024: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 177ms/sample - loss: 8.5218e-04 - val_loss: 1.1070
# Epoch 25/100
#
# Epoch 00025: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 178ms/sample - loss: 7.5768e-04 - val_loss: 1.1078
# Epoch 26/100
#
# Epoch 00026: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 173ms/sample - loss: 6.7638e-04 - val_loss: 1.1086
# Epoch 27/100
#
# Epoch 00027: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 173ms/sample - loss: 6.0599e-04 - val_loss: 1.1094
# Epoch 28/100
#
# Epoch 00028: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 177ms/sample - loss: 5.4472e-04 - val_loss: 1.1102
# Epoch 29/100
#
# Epoch 00029: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 178ms/sample - loss: 4.9111e-04 - val_loss: 1.1109
# Epoch 30/100
#
# Epoch 00030: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 168ms/sample - loss: 4.4402e-04 - val_loss: 1.1116
# Epoch 31/100
#
# Epoch 00031: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 206ms/sample - loss: 4.0245e-04 - val_loss: 1.1123
# Epoch 32/100
#
# Epoch 00032: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 239ms/sample - loss: 3.6565e-04 - val_loss: 1.1130
# Epoch 33/100
#
# Epoch 00033: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 200ms/sample - loss: 3.3289e-04 - val_loss: 1.1136
# Epoch 34/100
#
# Epoch 00034: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 219ms/sample - loss: 3.0370e-04 - val_loss: 1.1143
# Epoch 35/100
#
# Epoch 00035: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 193ms/sample - loss: 2.7760e-04 - val_loss: 1.1149
# Epoch 36/100
#
# Epoch 00036: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 176ms/sample - loss: 2.5416e-04 - val_loss: 1.1155
# Epoch 37/100
#
# Epoch 00037: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 169ms/sample - loss: 2.3309e-04 - val_loss: 1.1162
# Epoch 38/100
#
# Epoch 00038: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 172ms/sample - loss: 2.1409e-04 - val_loss: 1.1168
# Epoch 39/100
#
# Epoch 00039: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 178ms/sample - loss: 1.9691e-04 - val_loss: 1.1174
# Epoch 40/100
#
# Epoch 00040: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 172ms/sample - loss: 1.8133e-04 - val_loss: 1.1179
# Epoch 41/100
#
# Epoch 00041: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 167ms/sample - loss: 1.6720e-04 - val_loss: 1.1185
# Epoch 42/100
#
# Epoch 00042: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 177ms/sample - loss: 1.5435e-04 - val_loss: 1.1191
# Epoch 43/100
#
# Epoch 00043: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 173ms/sample - loss: 1.4265e-04 - val_loss: 1.1197
# Epoch 44/100
#
# Epoch 00044: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 167ms/sample - loss: 1.3198e-04 - val_loss: 1.1202
# Epoch 45/100
#
# Epoch 00045: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 172ms/sample - loss: 1.2223e-04 - val_loss: 1.1208
# Epoch 46/100
#
# Epoch 00046: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 172ms/sample - loss: 1.1330e-04 - val_loss: 1.1213
# Epoch 47/100
#
# Epoch 00047: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 172ms/sample - loss: 1.0513e-04 - val_loss: 1.1219
# Epoch 48/100
#
# Epoch 00048: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 167ms/sample - loss: 9.7642e-05 - val_loss: 1.1224
# Epoch 49/100
#
# Epoch 00049: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 167ms/sample - loss: 9.0762e-05 - val_loss: 1.1229
# Epoch 50/100
#
# Epoch 00050: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 173ms/sample - loss: 8.4443e-05 - val_loss: 1.1235
# Epoch 51/100
#
# Epoch 00051: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 172ms/sample - loss: 7.8621e-05 - val_loss: 1.1240
# Epoch 52/100
#
# Epoch 00052: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 173ms/sample - loss: 7.3244e-05 - val_loss: 1.1245
# Epoch 53/100
#
# Epoch 00053: val_loss did not improve from 1.05699
# 3/3 [==============================] - 0s 162ms/sample - loss: 6.8315e-05 - val_loss: 1.1250
# Epoch 54/100
#
# Epoch 00054: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 172ms/sample - loss: 6.3747e-05 - val_loss: 1.1255
# Epoch 55/100
#
# Epoch 00055: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 173ms/sample - loss: 5.9532e-05 - val_loss: 1.1260
# Epoch 56/100
#
# Epoch 00056: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 167ms/sample - loss: 5.5640e-05 - val_loss: 1.1265
# Epoch 57/100
#
# Epoch 00057: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 167ms/sample - loss: 5.2025e-05 - val_loss: 1.1270
# Epoch 58/100
#
# Epoch 00058: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 177ms/sample - loss: 4.8674e-05 - val_loss: 1.1275
# Epoch 59/100
#
# Epoch 00059: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 167ms/sample - loss: 4.5580e-05 - val_loss: 1.1279
# Epoch 60/100
#
# Epoch 00060: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 167ms/sample - loss: 4.2695e-05 - val_loss: 1.1284
# Epoch 61/100
#
# Epoch 00061: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 167ms/sample - loss: 4.0024e-05 - val_loss: 1.1289
# Epoch 62/100
#
# Epoch 00062: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 177ms/sample - loss: 3.7541e-05 - val_loss: 1.1294
# Epoch 63/100
#
# Epoch 00063: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 173ms/sample - loss: 3.5237e-05 - val_loss: 1.1298
# Epoch 64/100
#
# Epoch 00064: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 172ms/sample - loss: 3.3102e-05 - val_loss: 1.1303
# Epoch 65/100
#
# Epoch 00065: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 167ms/sample - loss: 3.1095e-05 - val_loss: 1.1307
# Epoch 66/100
#
# Epoch 00066: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 177ms/sample - loss: 2.9243e-05 - val_loss: 1.1312
# Epoch 67/100
#
# Epoch 00067: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 167ms/sample - loss: 2.7510e-05 - val_loss: 1.1316
# Epoch 68/100
#
# Epoch 00068: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 172ms/sample - loss: 2.5896e-05 - val_loss: 1.1321
# Epoch 69/100
#
# Epoch 00069: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 168ms/sample - loss: 2.4391e-05 - val_loss: 1.1325
# Epoch 70/100
#
# Epoch 00070: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 177ms/sample - loss: 2.2996e-05 - val_loss: 1.1330
# Epoch 71/100
#
# Epoch 00071: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 168ms/sample - loss: 2.1689e-05 - val_loss: 1.1334
# Epoch 72/100
#
# Epoch 00072: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 172ms/sample - loss: 2.0473e-05 - val_loss: 1.1338
# Epoch 73/100
#
# Epoch 00073: val_loss did not improve from 1.05699
# 3/3 [==============================] - 0s 162ms/sample - loss: 1.9326e-05 - val_loss: 1.1342
# Epoch 74/100
#
# Epoch 00074: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 172ms/sample - loss: 1.8268e-05 - val_loss: 1.1346
# Epoch 75/100
#
# Epoch 00075: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 167ms/sample - loss: 1.7274e-05 - val_loss: 1.1350
# Epoch 76/100
#
# Epoch 00076: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 167ms/sample - loss: 1.6341e-05 - val_loss: 1.1354
# Epoch 77/100
#
# Epoch 00077: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 172ms/sample - loss: 1.5482e-05 - val_loss: 1.1358
# Epoch 78/100
#
# Epoch 00078: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 172ms/sample - loss: 1.4647e-05 - val_loss: 1.1362
# Epoch 79/100
#
# Epoch 00079: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 168ms/sample - loss: 1.3872e-05 - val_loss: 1.1365
# Epoch 80/100
#
# Epoch 00080: val_loss did not improve from 1.05699
# 3/3 [==============================] - 0s 166ms/sample - loss: 1.3172e-05 - val_loss: 1.1369
# Epoch 81/100
#
# Epoch 00081: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 177ms/sample - loss: 1.2497e-05 - val_loss: 1.1372
# Epoch 82/100
#
# Epoch 00082: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 173ms/sample - loss: 1.1861e-05 - val_loss: 1.1375
# Epoch 83/100
#
# Epoch 00083: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 172ms/sample - loss: 1.1265e-05 - val_loss: 1.1379
# Epoch 84/100
#
# Epoch 00084: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 184ms/sample - loss: 1.0714e-05 - val_loss: 1.1382
# Epoch 85/100
#
# Epoch 00085: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 260ms/sample - loss: 1.0182e-05 - val_loss: 1.1385
# Epoch 86/100
#
# Epoch 00086: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 201ms/sample - loss: 9.6904e-06 - val_loss: 1.1388
# Epoch 87/100
#
# Epoch 00087: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 190ms/sample - loss: 9.2285e-06 - val_loss: 1.1391
# Epoch 88/100
#
# Epoch 00088: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 216ms/sample - loss: 8.7865e-06 - val_loss: 1.1393
# Epoch 89/100
#
# Epoch 00089: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 253ms/sample - loss: 8.3693e-06 - val_loss: 1.1396
# Epoch 90/100
#
# Epoch 00090: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 251ms/sample - loss: 7.9719e-06 - val_loss: 1.1399
# Epoch 91/100
#
# Epoch 00091: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 176ms/sample - loss: 7.6243e-06 - val_loss: 1.1401
# Epoch 92/100
#
# Epoch 00092: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 175ms/sample - loss: 7.2716e-06 - val_loss: 1.1403
# Epoch 93/100
#
# Epoch 00093: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 172ms/sample - loss: 6.9488e-06 - val_loss: 1.1406
# Epoch 94/100
#
# Epoch 00094: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 176ms/sample - loss: 6.6408e-06 - val_loss: 1.1408
# Epoch 95/100
#
# Epoch 00095: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 183ms/sample - loss: 6.3478e-06 - val_loss: 1.1410
# Epoch 96/100
#
# Epoch 00096: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 170ms/sample - loss: 6.0845e-06 - val_loss: 1.1412
# Epoch 97/100
#
# Epoch 00097: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 193ms/sample - loss: 5.8213e-06 - val_loss: 1.1414
# Epoch 98/100
#
# Epoch 00098: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 171ms/sample - loss: 5.5829e-06 - val_loss: 1.1415
# Epoch 99/100
#
# Epoch 00099: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 169ms/sample - loss: 5.3544e-06 - val_loss: 1.1417
# Epoch 100/100
#
# Epoch 00100: val_loss did not improve from 1.05699
# 3/3 [==============================] - 1s 190ms/sample - loss: 5.1359e-06 - val_loss: 1.1418

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['train','validation'])
plt.show()

# %%
import tensorflow as tf
tf.keras.backend.set_learning_phase(0)
Converter = tf.lite.TFLiteConverter.from_keras_model(model)
Converter.experimental_new_converter = True
Tflite_model = Converter.convert()
open("converted_model3G.tflite", "wb").write(Tflite_model)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14032\2964659001.py in <module>
#       1 import tensorflow as tf
#       2 tf.keras.backend.set_learning_phase(0)
# ----> 3 Converter = tf.lite.TFLiteConverter.from_keras_model(model)
#       4 Converter.experimental_new_converter = True
#       5 Tflite_model = Converter.convert()
#
# AttributeError: type object 'TFLiteConverter' has no attribute 'from_keras_model'

# %%
#model = tf.keras.models.load_model('model_23_11_19')
preds = model.predict_classes(testX.reshape((testX.shape[0],testX.shape[1])))

preds.shape
# Out:
# (876, 8)

# %%
import numpy as np
X_in = [3,189,48,280,0,0,0,0]
t = model.predict(np.reshape(X_in,(1,8)))

np.argmax(t, axis=2)
# Out:
# array([[   2,   73,  570, 1249,  783,    0,    0,    0]], dtype=int64)

# %%
X_in = [3,0,0,0,0,0,0,0]
t = model.predict(np.reshape(X_in,(1,8)))

np.argmax(t, axis=2)
# Out:
# array([[ 18, 552,   0,   0,   0,   0,   0,   0]], dtype=int64)

# %%
testX.reshape((testX.shape[0],testX.shape[1]))
# Out:
# array([[  3, 545, 139, ...,   0,   0,   0],
#        [  1,  69,  57, ...,   0,   0,   0],
#        [ 32,  22, 138, ..., 126,   0,   0],
#        ...,
#        [ 24,  95,  20, ...,   0,   0,   0],
#        [  8, 471,   0, ...,   0,   0,   0],
#        [  1,  68, 819, ...,   0,   0,   0]])

# %%
trainX[0] #INPUT
# Out:
# array([ 22,   1, 111,   2, 151, 559,   0,   0])

# %%
def get_word(n, tokenizer):
      for word, index in tokenizer.word_index.items():
          if index == n:
              return word
      return None

# %%
#deu_tokenizer
#eng_tokenizer
get_word(64,deu_tokenizer)  #INPUT
# Out:
# 'পারি'

# %%
get_word(111,eng_tokenizer) #OUTPUT
# Out:
# 'ask'

# %%
preds_text = []
for i in preds:
       temp = []
       for j in range(len(i)):
            t = get_word(i[j], deu_tokenizer)
            if j > 0:
                if (t == get_word(i[j-1], deu_tokenizer)) or (t == None):
                     temp.append('')
                else:
                     temp.append(t)
            else:
                   if(t == None):
                          temp.append('')
                   else:
                          temp.append(t) 

       preds_text.append(' '.join(temp))

# %%
pred_df = pd.DataFrame({'actual' : test[:,0],'actual2' : test[:,1], 'predicted' : preds_text})

# %%
test[:,1]
# Out:
# array(['টম গেটের বাইরে অপেক্ষা করলো।', 'আমি ওকে দৌড়াতে দেখেছিলাম।',
#        'তার যা ইচ্ছে সে বলতে পারে।', 'কোনো ভুল নেই।', 'তিনি ফল খাচ্চেন।',
#        'ও এখনো আসেনি।', 'টম চিৎকার করলো।', 'এটা আমার নয়।',
#        'এখানে দাঁড়ান।', 'আমরা কফি পছন্দ করি।', 'টম কি বাড়িতে আছে',
#        'আমার এটা প্রয়োজন ছিলো।', 'আপনার গাড়ি আছে', 'তোমার উত্তর ভুল।',
#        'টমের বাবামাও গায়ক ছিলেন।', 'আমি কোথা থেকে আমার মালপত্রটা পাব',
#        'আপনি খুব সাহসী।', 'এখানে সই করুন।', 'সবাই পরিশ্রান্ত।',
#        'আমি আর টম একলা ছিলাম।', 'আমি সেটা ব্যবস্থা করে দেবো।',
#        'ও ভালো মানুষ।', 'তারা চেঁচালো।', 'আমি ভেতরে আছি।',
#        'টম চেঁচাতেই থাকলো।',
#        'সে প্যারিস গেছে তার কাকিমার সঙ্গে দেখা করতে।',
#        'আমি কি এখানে কাজ করতে পারি',
#        'ও কী করে না করে আমি তা কেয়ার করি না।', 'টম এত খুশি কখনো হয় নি।',
#        'নিজেকে সংজত করো।', 'চেখে দেখো।',
#        'তোমাকে ছাড়া এটা করতেই পারতাম না। ধন্যবাদ।', 'তিনি আসতে পারেন।',
#        'আমরা যা করতে চাই তাই করি।', 'ঘরের মধ্যে দিয়ে টম মেরির দিকে চাইল।',
#        'তিনি এখনো এসে পৌছাননি।', 'ও বক্তৃতা দিচ্ছিলো।', 'আপনারা দৌড়ান।',
#        'আমি এখনো তোর বন্ধু আছি।', 'এটা পৃথিবীর তৃতীয় দীর্ঘতম নদী।',
#        'সবকিছুই আলোচনাসূত্রে মীমাংসাযোগ্য।', 'কে ছিলো',
#        'আমার একটা বেড়াল ছিলো।',
#        'আমি খালি ফরাসি আর একটু ইংরাজিতে কথা বলতে পারি।',
#        'চিৎকার করা বন্ধ করুন।', 'উনি কে', 'আমি পাহারা দেব।',
#        'টম বেসবল সম্বন্ধে অনেক কিছু জানে বলে মনে হচ্ছে।',
#        'বাচ্চারা এগুলো করতে ভালোবাসে।', 'এখন প্রায় ছটা বাজে।',
#        'আপনি কী খাবেন', 'ওই শব্দটার মানে কী', 'এই নাও তোমাদের চাবি।',
#        'আপনি কি অসুস্থ', 'আমার বাবা লম্বা।', 'আমি এটায় গর্বিত নই।',
#        'আমি ওদের দেখতে পেলাম।', 'শুভ সন্ধ্যা।',
#        'আমি ৭ঃ০০টার ট্রেনটা ধরতে পারিনি।', 'আমি ওনাকে দৌড়াতে দেখেছিলাম।',
#        'স্টেশন অবধি হেঁটে যেতে কতক্ষণ লাগে', 'এটা আমাকে পাগল করে দিচ্ছে।',
#        'তোমার যা চাই তাই খাও।', 'টম চেঁচাচ্ছে।',
#        'আমি আপেল খেতে পছন্দ করি।', 'টম এখানে ২০১৩ থেকে কাজ করছে।',
#        'আমি বুঝে গেছি।', 'আপনি কী পেয়েছেন', 'আমরা পার্কে খেলতাম।',
#        'জাপানে কবে থেকে আলুর প্রবর্তন হয়ছিল', 'পাখি গান গায়।',
#        'তুমি কি এক মিনিটের জন্য অপেক্ষা করতে পারবে', 'তুমি কেমন আছো',
#        'ও জানে আমরা কোথায় থাকি।', 'ও ফল ছাড়া আর কিছুই খায় না।',
#        'টম রেগে গেছিলো।', 'উনি ফল খাচ্ছেন।', 'বাঁদিকে ঘোরো।',
#        'আমি গতকাল হাসপাতালে গেছিলাম।', 'উনি ভালো মানুষ।',
#        'আপনি এমনিতে লাঞ্চ কটার সময় খান', 'আমি এবার বেরোবো।',
#        'আমি ওর সাথে একমত নই।', 'টম ওর অফিসে রয়েছে।', 'টম এখন স্বর্গে।',
#        'টমকে চুমু করুন।',
#        'আমি জানি আমি কি চাই। খালি আমি সেটা এখনো খুজে পাইনি।',
#        'আমি তোমাকে এটা একশবার বলেছি।', 'আপনি এখানে কি জন্যে এসেছেন',
#        'আমি আপনার ফোন নাম্বারটা হারিয়ে ফেলেছি।',
#        'আমার ইচ্ছা যে আপনি টমের সঙ্গে কথা বলেন।', 'আপনি পড়তে পারেন',
#        'আস্তে হাঁটুন।', 'টম কত সুখি মানুষ ছিল।', 'ওটার মানে কী',
#        'সবাই এখানে আছেন।',
#        'আমার যখন তেরো বছর বয়স তখন আমাকে কেউ একজন বলেছিলো যে আমি নাকি ফরাসিতে খুব ভালো।',
#        'এই অষুধটা আমি আমার বাবার জন্য কিনেছি।', 'এটা আমার নয়।',
#        'বিবাহবিচ্ছেদ এখনকার দিনে খুবই সাধারণ হইয়ে গেছে।',
#        'আমি আপনার নাম জানি।', 'তিনি কে',
#        'আমার মা প্রত্যেকদিন বাজারে যায় জিনিস কিনতে।', 'তারাতারি কর টম।',
#        'আমি অনেক ছবি তুলেছি।', 'তাহলে',
#        'আমি আমার স্ত্রীএর জন্য একটা গিফট খুজছি।', 'একটু হাসো।',
#        'আপনি প্রথমে যান।', 'আমার কেক ভালো লাগে।', 'টেবিলে ওই বইটা কার',
#        'ওনারা কারা', 'সবাই এটা দেখেছিলো।',
#        'আমার প্রতিবেশীর নাম টম জ্যাকসন।', 'সবাই তৈরি।',
#        'ও ফল ছাড়া অন্য কিছু খায় না।', 'আপনি ভাল করেই জানেন টম কি চায়।',
#        'আমার আর সেটা দরকার নেই।', 'আমরা ফরাসি ভাষা বলি।',
#        'আমি এখন ঘাবড়িয়ে আছি।', 'এখানে কি হয়েছে', 'হ্রদটা কি খুব গভীর',
#        'টিকিটটি ভুলে যেও না।', 'আমি ঈর্ষাপরায়ণ নই।',
#        'আমার জীবনবিজ্ঞান কখনই ভালো লাগেনি।', 'বুঝলাম।',
#        'আমি কিছু একটা দেখলাম।', 'উনি ভাঙ্গা টুকরোগুলো জোড়া লাগালেন।',
#        'এটা কি স্টেশনে যাওয়ার রাস্তা', 'তাদের মধ্যে একজন গুপ্তচর।',
#        'কেউই কথা বলছে না।', 'আমার মনে হয় টম ভালোই আছে।',
#        'টম কাজ নিয়ে খুব ব্যস্ত ছিল।', 'পুলিশ আমাদের পেছনে যেতে আদেশ দিল।',
#        'আমি এটা দেখেছি।', 'আমার পেট ভরতি হয়ে গেছে।',
#        'আমার পিঠ ব্যাথা করছে।', 'টম আপনার সঙ্গে দেখা করতে চায় না।',
#        'টম আপনাদের প্রশ্নের উত্তর দেবে।',
#        'ভারী কুয়াশার জন্য একজনকেও দেখা যাচ্ছিলো না।',
#        'আমাকে কাল সকাল ছটায় ফোন করবেন।', 'ওরা সবাই চেঁচালো।',
#        'আমার আর তোমাকে ভালো লাগে না।', 'আমরা শুনলাম টম ঝামেলায় পরেছিল।',
#        'টম আহত।', 'এটা কি সাম্প্রতিক ছবি',
#        'টম তোমার সাথে কথা বলতে চেয়েছিল।', 'আমাকে ডেক।',
#        'আমি এই চিঠিটার উত্তর দিতে চাই না।', 'বাইরে আসুন।',
#        'আমার এক ভাই আছে।', 'টম অদৃশ্য হয়ে গেলো।',
#        'উনি সন্ধ্যেবেলা বই পড়ে কাটান।', 'আমি এখনই ঘরটা ছেড়ে দিতে চাই।',
#        'মুখ খুলুন', 'এভারেট প্রায় দু ঘন্টা ধরে কথা বলেছিল।',
#        'টম খুব অসুস্থ।', 'তুমি আমার প্রতি বড্ড অধৈর্য্য।',
#        'আপনার কি মনে হয় আমি কি করছিলাম',
#        'আমাদেরকে কোন অংশে কম মনে করবেন না।', 'আমি ঠিক আছি।',
#        'টম জ্যাকসন কি আপনার আসল নাম', 'আমি টমকে কিছু জিজ্ঞাসা করতে চাই।',
#        'এটাকে কি অন্যভাবে বলা যায়', 'সন্ধ্যেবেলা বরফ পরতে পারে।',
#        'টম অনেক দৌড় জিতেছে।', 'টম আমার সঙ্গে সারা দিন ছিল।',
#        'ট্রেনটা সময় মতোই এসেছিলো তাই আমাদের একদমই অপেক্ষা করতে হয়নি।',
#        'উনি কে', 'আমি জাপানি ভাষায় কথা বলি না।',
#        'আমার স্কুল যেতে দেরী হয়েগেছিল।', 'আমি আমার ছেলের উপর গর্বিত।',
#        'আপনারা কি ভেতরে আসবেন', 'আমরা এটা পরেও শেষ করতে পারি।',
#        'আমরা ফুটবল খেলা পছন্দ করি।', 'থামো', 'তোমরা আসতে পারবে না কেন',
#        'ফুটবল আমার প্রিয় খেলা।', 'আমরাও এখানে আছি।',
#        'টম ওনার মুখ উঁচু রাখার চেষ্টা করেছিলেন।', 'তোমরা কি ভেতরে আসবে',
#        'তাঁর যা ইচ্ছে তিনি বলতে পারেন।', 'টম ওখানে থাকে।',
#        'আমি সত্যি সত্যিই টমের জন্য খুশি হয়েছি।',
#        'আমার খুব ভালো ফরাসি অভিধান আছে।', 'আমি সবে বাড়ি পৌছালাম।',
#        'চলে যান।', 'টম ওনাকে দেখলো।', 'আমি অলস।', 'আমি ইংরাজি পরতে পারি।',
#        'আমার সময় আছে।', 'টমের কথা ভুলে যান।', 'টম তোমাদের দেখলো।',
#        'বাড়িতে কি কেউ আছে', 'কে খেয়েছিল', 'আমি খেলাধুলায় খারাপ।',
#        'একজনের জন্য কত টাকা লাগবে', 'টম চূড়ান্তভাবে অপদস্ত হোল।',
#        'আপনারা কী করছেন', 'ওনারা জিতলেন।',
#        'টম মেরি দ্বারা অপদস্ত হয়েছিলো।', 'টম আমাকে ফরাসি পড়ায়।',
#        'টম এখনো বিছানায়।', 'আমি তোর বন্ধু নই।', 'আমি এটা চেয়েছিলাম।',
#        'অনুগ্রহ করে নুনটা এগিয়ে দেবেন। এই নিন।',
#        'তাদের দুটো জমজ মেয়ে আছে।', 'আগে থেকেই সংরক্ষণটি হয়ে গেছে।',
#        'আমি টমের মা।', 'সবাই ঘুমাতে চলে গেলো।',
#        'টম সবসময় ওনার কথা রাখেন।', 'আমিই কেন', 'তুমি কি অসুস্থ',
#        'আমি হাসপাতাল সহ্য করতে পারি না।', 'টম চিৎকার করছে।',
#        'টম আমাকে ছেড়ে চলে গিয়েছিল।', 'আমি বাড়িয়ে বললাম।', 'এটা কেনো ঘটলো',
#        'টম চায় আমি ওর সঙ্গে যাই।', 'আমি পাহাড়ে ছিলাম।',
#        'টম কাশতে শুরু করলো।', 'আমার মনে হয় না টম আপনাকে পছন্দ করে।',
#        'সবাই এখানে আছেন।', 'সবকিছুই আলোচনাসূত্রে মীমাংসাযোগ্য।',
#        'টম হেরে গেলো।', 'এ আমার থেকে ছোট।', 'টম মনযোগ দিয়ে শুনছে।',
#        'ওনারা আমাকে মাঝেমধ্যে দেখতে আসতেন।', 'পালান',
#        'তিনি ফল ছাড়া অন্য কিছু খান না।', 'একটু ঘুমিয়ে নিন।',
#        'আমি একদমই ক্লান্ত নই।', 'আরও চেষ্টা করুন।',
#        'টম মেরিকে ভয় দেখালো।', 'আমি তার সাথে একমত নই।', 'ও ভালো মানুষ।',
#        'ও আমার সঙ্গে হাসপাতালে গেছিল।', 'এই ঘড়িটার দাম কত',
#        'তুমি কি আমাদের সাথে মাছ ধরতে যাবে', 'টম মারা গেছে।',
#        'এটা কি তোর গাড়ি', 'টম আসছে।',
#        'আমি ওয়েটার হিসাবে তিন বছর কাজ করেছি।',
#        'তিনি ফল ছাড়া আর কিছুই খান না।', 'চলো তৈরী হওয়া যাক।',
#        'ও আমার স্ত্রী।', 'আমি আমার টিকিটটি বাতিল করতে চাই।',
#        'তিনি খাচ্ছেন।', 'আপনি কি ওখানে ছিলেন', 'সে একজন ডাক্তার।',
#        'আমি সংরক্ষণটি তিন দিন থেকে পাঁচ দিনে পালটাতে চাই।',
#        'আমি ট্রেনে বারো ঘন্টা কাটিয়েছি।', 'টমকে হাসানোর চেষ্টা করা যাক।',
#        'কার কী এসে যায়', 'আসিস না।', 'আপনি যত ইচ্ছে তত খেতে পারেন।',
#        'এটার দাম কত', 'ও আমার মেয়ে।', 'আপনার কাছে কি আরো বড় বাটি আছে',
#        'টম সারাদিন ধরে মাথা যন্ত্রনায় ভুগছে।', 'আমি আগে ফোন করবো।',
#        'টম সাধারণত দশটা চল্লিশ নাগাদ শুতে যায়।', 'ফরাসি আমার মাতৃভাষা।',
#        'ফরাসি কঠিন নয়।', 'আমি যাবো।', 'আমি ওকে ছাড়া বাঁচতে শিখেছি।',
#        'টম আহত হয়েছে।', 'তাঁরা চেঁচালেন।', 'আমি সবকিছুই খাই।',
#        'আমি এতে খুব একটা ভালো নই।', 'আপনি ওখানে বসে আছেন কেন',
#        'আপনারা কি করেন', 'তুমি এখন খেতে চাও কি না',
#        'টম আমাকে বারবার বাধা দিচ্ছিলেন।', 'বুঝে গেছি',
#        'ছাত্রছাত্রীদের জন্য কোনো ছাড় আছে',
#        'আমি আমার নাম পাল্টে টম জ্যাকসন রেখেছি।', 'আমি তোমার সাথে একমত।',
#        'আমাকে আগামীকাল ফোন করবে।', 'আস্তে যান।',
#        'আমার কাছে এটা গুরূত্বপুর্ণ।', 'আমার আর ওটা দরকার নেই।',
#        'তুমি কোথায়', 'সবাই চিৎকার করলেন।', 'আমি তোমাকে চেঁচাতে শুনলাম।',
#        'আপনাদের পার্টিতে কতজন লোক আছে', 'আমি ওটা অস্বীকার করছি না।',
#        'কেমন আছো যাত্রা ভালো ছিল তো', 'তোমার কোনটা দরকার আমাকে বলো।',
#        'আমার বাবা প্লেন ওড়াতে পারে।',
#        'টোকিওর জন্য পরের ট্রেনটা কটার সময় ছাড়ে', 'এই শব্দটার অর্থ কী',
#        'ও একটু বেশিই খায়।', 'টম মেরিকে থাপ্পর মারলো।', 'আমি খেয়াল করিনি।',
#        'টম প্রায় প্রত্যেক দিন কেঁদেছে।', 'টমের ওখানে থাকা উচিৎ ছিলো।',
#        'এখানে কাছাকাছির মধ্যে কোনো হাসপাতাল আছে',
#        'অনুগ্রহ করে আপনার পাসপোর্টটি দেখাবেন', 'সুপ্রভাত।',
#        'আপনি কি এখনো বই পড়েন',
#        'আমাদের খালি টমকে আমাদের হয়ে এই কাজটা করে দিতে বলতে হবে তাই না',
#        'বাঁদিকে ঘুরুন।', 'টম আমাকে চিমটি কাটলো।', 'আমার ওকে ভালো লাগে।',
#        'আবার পরে জিজ্ঞাসা করবেন।', 'টম খালি মাছই ধরতে চায়।',
#        'আপনারা কি আমার কথা বুঝতে পারছেন', 'গল্প করা যাক।',
#        'আপনি ভুল রাস্তায় যাচ্ছেন।', 'তুমি বোঝ না।',
#        'আমি অবশেষে টমকে দাবায় হারিয়েছি।', 'ওই মহিলাটিকে আটকাও।',
#        'সবাই সেটা দেখেছিলো।', 'এটা আমার বোন।',
#        'তোমাকে প্রত্যেকদিন বেহালা বাজানো অভ্যাস করতে হবে।',
#        'ওই কুকুরটার বয়স কত', 'বুঝেছো', 'তুমি আমার রাস্তা আটকে রেখেছো।',
#        'আমি ৪ঠা জুন ১৯৭৪ এ জন্মগ্রহণ করেছিলাম।',
#        'আমি এরমধ্যেই আমার জামাকাপর পালটে ফেলেছি।',
#        'বরফ অতিবেগুনী রশ্মিকে প্রতিফলিত করে।', 'নিজে এসেই দেখে যাও।',
#        'আমার বইটা এখানে।', 'টম সাহায্য করলো।',
#        'আমি জানিনা এটা করার জন্য সময় পাব কি না।', 'এখন কটা বাজে',
#        'ওনার হাতের লেখা দেখতে খুব সুন্দর।',
#        'একটু শান্ত থাকার চেষ্টা করুন।', 'টম কি এখানে আছে',
#        'তুমি চিৎকার করছো।', 'আমি টম নই।',
#        'আপনার যা কিছু পছন্দ হয় তাই খান।',
#        'আমি এখান থেকে চিড়িয়াখানায় কিভাবে যাব', 'টম আহত হয়েছে।',
#        'টমকে আটকান।', 'আমার এটা চাই।', 'তিনি সন্ধ্যেবেলা বই পরে কাটান।',
#        'আমি ভাবছি তোমাকে জন্মদিনে কী দেবো।', 'ভুল হয়েই থাকে।',
#        'নিজেকে সংজত করুন।', 'পরের মোড়টায় ডানদিকে বেঁকে যাবেন।',
#        'আমি সহজেই ওর বাড়ি খুজে পেয়েছিলাম।', 'এনারা পরোয়া করেন না।',
#        'মুখ খোলো', 'ঘুম থেকে ওঠ।', 'টমকে কথা বলতে দাও।',
#        'আপনার ফোন নাম্বারটা কী', 'এই নদীটি প্রশান্ত মহাসাগরে গিয়ে পড়ে।',
#        'আপনাকে দেখে খুব ফ্যাকাশে লাগছে।', 'আমি আপেল ভালোবাসি।',
#        'হয়তো বরফ পরবে।', 'আমার মনে হয় টমের পক্ষে এটা অসম্ভব।',
#        'হোটেলটি গত বছর তৈরি হয়েছিল।',
#        'আমার বাবা খুব ভাল গাড়ি চালাতে পারে।', 'ও আমার থেকে ছোট।',
#        'আমি একটা সিনেমা হলে ছিলাম।', 'আমাদেরকে খুব তাড়াতাড়ি চলতে হবে।',
#        'আমি কি ক্রেডিট কার্ড ব্যবহার করতে পারি', 'ওটার মানে কী',
#        'আমরা সারা দুপুর পরাশুনা করছিলাম।',
#        'তিনি যেখানে যেতেন তাঁর কুকুর তাঁর পছনে পেছনে যেত।',
#        'তিনি জাপানি বলতে পারেন।', 'সে এখনো আসেনি।', 'আপনি বড়লোক।',
#        'আপনার প্লেনটা কটার সময় ছাড়বে', 'আমার তৃষ্ণা পায় নি।',
#        'আমি আমার টিকিটটি পালটাতে চাই।', 'তুমি কোথায় থাকো', 'তুমি কী করছো',
#        'আমি পড়ছি।', 'আমি একটা গেস্ট হাউস কোথায় পাব বলতে পারবেন',
#        'টম খেয়েছে।',
#        'অনুগ্রহ করে আমাদের জন্য দু কাপ চা আর এক কাপ কফি নিয়ে আসবেন।',
#        'আমি যা বলছি আপনি কি তা বুঝতে পারছেন', 'সে পড়াশুনায় অবহেলা করে।',
#        'আমারা সমস্যাটার ব্যাপারে এখনো নিশ্চিত হইনি।',
#        'টমকে আমন্ত্রন জানাতে ভুলো না।', 'আমি জিতে গেছি।',
#        'আপনাদের কি ঘর খালি আছে', 'সবাই খুশি ছিলো।', 'আমি হাসপাতালে আছি।',
#        'টম তোমার সঙ্গে দেখা করতে চায় না।',
#        'আপনি বস্টনে কোনো ভাল হোটেলের সুপারিশ করতে পারবেন',
#        'আপনার বাচ্চাদের বয়স কত', 'ও এখনো আসেনি।', 'টম কি খেয়েছে',
#        'টম চিৎকার করলো।', 'ওরা চেঁচালো।', 'তুমি কটার সময় ঘুম থেকে ওঠো',
#        'আমাকে দেখা।', 'টমকে অনুসরণ করুন।',
#        'আপনি হয়তো ভাবছেন আমি কি করে ওই ব্যাপারটা জানতে পারলাম।',
#        'টম মাথা নাড়লো।', 'তারা ডাক্তার।',
#        'আপনি কি টমকে চারপাশটা দেখিয়ে আনতে পারবেন', 'আমি একদম পাগল।',
#        'আমি এখানি কাজ করি।', 'তুমি কি ফরাসি ভাষা বলতে পারো', 'তোর নাম কি',
#        'টম আমি মেরির সঙ্গে কথা বলতে চাই।',
#        'আমি কাল যখন ফিরবো ওদেরকে একবার কল করবো।', 'আপনার নাম কি',
#        'আমি কি এটা একটু দেখেতে পারি', 'আমি কাঁদতে চাই।',
#        'আমি আমার ভালো বন্ধু টমকে ফোন করেছিলাম।', 'এটা কি আপনার বই',
#        'আমার জন্য কি আদেশ আছে', 'এখন ৭৪৫।', 'এখানেই থামুন।',
#        'এখান থেকে স্টেশন যেতে কতক্ষণ লাগে',
#        'আমি টমের সঙ্গে কথা বলতে চাই না।', 'ওটা কত',
#        'অনুগ্রহ করে আপনার পাসপোর্টটি দেখাবেন।', 'আপনি কি ওখানে আছেন',
#        'আপনি কি আমার কথা বুঝতে পারছেন', 'আমি ভেতরে গেলাম।',
#        'আমি এসে গেছি।', 'এটা আমার ছোটো বোন।', 'কে জিতল',
#        'ও পরের এপ্রিলে দশ বছরের হবে।', 'আমি ভেতরে।', 'এই বইটা কি তোমার',
#        'যাও এখান থেকে', 'টম খুব ভালো রান্না করতে পারে।',
#        'আমি তিনটে বিস্ফোরণের আওয়াজ শুনলাম।', 'আবার করুন',
#        'টম চেঁচানো আরম্ভ করলো।', 'ওই লোকটা টম।',
#        'টম বারে দাঁড়িয়ে বিয়ার খাচ্ছিল।',
#        'পরের মোড়টায় ডানদিকে বেঁকে যাবেন।', 'আপনার কি সাইকেল নেই',
#        'আমায় ক্ষমা করবেন আমি বেশিক্ষণ থাকতে পারবো না।',
#        'এটা সম্পুর্ণ আলাদা।', 'উনি ক্যানেডিয় নাগরিক।',
#        'জাদুঘরে ঢোকার দরজাটি কোথায়', 'নিজেকে বিভ্রান্ত কোরো না।',
#        'টম ভাবলেন যে তাবিজটা ওনাকে ডাইনিদের হাত থেকে বাঁচাবে।',
#        'কথা বোল না।', 'আমরা কি তৈরি', 'আপনি কি মাংস খান',
#        'আমরা চেষ্টা করেছিলাম।', 'আমি তোদের বন্ধু নই।',
#        'ভেতরে একটা ঘর আছে।', 'আপনাদের যে খাবার পছন্দ হয় সেটা খান।',
#        'ও কে', 'ডাক্তারের সাথে পরামর্শ করুন।', 'দারুন', 'কে এলো',
#        'আমি যা ভেবেছিলাম তার থেকে অনেক সস্তা ছিল।',
#        'টম আমাদের কতো কিছু দিয়েছে।', 'তিনি ফল ছাড়া অন্য কিছু খান না।',
#        'টম সবসময় ওর কথা রাখে।', 'ইনি এই বিষয় কথা বলতে চান না।',
#        'টম কোথায় গেছিল', 'টম ওর বাচ্চাদের নিতে এসেছে।',
#        'আমাদের দুটো মেয়ে আছে।', 'আমি দিনে €১০০ আয় করি।',
#        'সাবধানে গাড়ি চালান।', 'আমি তোর পাশে বসলে কিছু মনে করবি',
#        'আমি ঠিক।', 'টম ওর আত্বীয়দের সাথে থাকছে।', 'এই নিন আপনাদের চাবি।',
#        'আমি বিলটা মিটিয়ে দেব।', 'আমি জানিনা তুমি কোথায় যেতে চাও।',
#        'তোমার মেয়ে আর বাচ্চা নেই।', 'কার কার খিদে পেয়েছে', 'ও কে',
#        'কার চা চাই', 'কে চেঁচাচ্ছে', 'ওখানে কিছুই নেই।',
#        'আমি আপনার সাথে যেতে পারতাম কিন্তু আমার সময় ছিল না।',
#        'এটা ওর বাড়ি।', 'এই বাড়িটা আমার ঠাকুরদার।', 'ওইদিকে দেখুন।',
#        'আমাকে দোকানে যেতে হবে। আমি এক ঘন্টার মধ্যেই ফিরে আসবো।',
#        'ওখানে দেখা হবে।', 'টম পরের বসন্তে বস্টন যাওয়ার কথা ভাবছে।',
#        'আপনি এমনিতে দুপুরের খাবার কটার সময় খান',
#        'আমার মনে হয় তোমরা দুজনেই টমকে চেনো।',
#        'আমি এই আশেপাশেই কোথাও আমার চাবি হারিয়ে ফেলেছি।',
#        'আপনি কি আসতে চান', 'আমি বাড়ি পালিয়ে গেছিলাম।',
#        'আমি বুঝতে পারছি না।', 'আমার মা জানে কিভাবে কেক বানাতে হয়।',
#        'আমি হারবো না।', 'আমার কাছে ওয়াইন আছে।',
#        'কাল বৃষ্টি হলেও আমি সাঁতার কাটতে যাবো।', 'টমকে বলো।',
#        'আমি আমার মালপত্র হারিয়ে ফেলেছি।',
#        'টম যেহেতু ফরাসি ভাষায় কথা বলছিলো আমি ওর কথা কিছুই বুঝতে পারছিলাম না।',
#        'ওই বইটা ফরাসিতে লেখা হয়েছে।', 'উনি কি শিক্ষক',
#        'ওনারা যা করেছেন সেটা ভুল।', 'টম মেরিকে নিয়ে একটা গান লিখলো।',
#        'আমার ওই ব্যাগটা চাই।', 'আমি তোমাকে বিশ্বাস করি।',
#        'আমি তোমার উপর নির্ভর করে আছি।',
#        'আমি কি আপনার পাসপোর্টটি দেখতে পারি', 'ভেতরে ফিরে যান।',
#        'আমাকে হাসপাতালে নিয়ে চলুন।', 'তুমি যত ইচ্ছে তত খেতে পা্রো।',
#        'এবার ওটা ঠিক করো।', 'আমি বিমানে করে আমেরিকা যাচ্ছি।',
#        'আমি টমকে জাগাতে চাই না।', 'উনি খাচ্ছেন।',
#        'আমার প্রশ্নের জবাব দিন।', 'এটা আমাকে পাগল করে দিচ্ছে।',
#        'টম নিজের কাজের পদ্ধতিতে বেশ নিয়মনিষ্ঠ।',
#        'আপনি এই পুরষ্কারটির যোগ্য।', 'আমাকে দেখাও।',
#        'কথা বলতে বলতে কফি খাওয়া যাক।', 'আমরাই জিতব।',
#        'তোমার দাদুর বয়স কত', 'আমার ব্যপারে চিন্তা কোর না।', 'পালাও',
#        'টম জোরে কাশলো।', 'তিনি কে', 'তুমি কি ওখানে আছো',
#        'টম আপনার ব্যাপারে আমাকে সব বলেছে।',
#        'যখন বাড়ি ফিরলাম তখন দেখলাম আমি আমার মানিব্যাগটি হারিয়ে ফেলেছি।',
#        'তোমার মা গতকাল মারা গেছেন।', 'ওটা আমার উদ্দেশ্য ছিল না।',
#        'সবাইকে সুপ্রভাত।', 'এই হোল আমার ফোন নাম্বার।',
#        'আমি খালি ফরাসি ভাষায় কথা বলি।', 'এটার দাম পড়বে €৩০।',
#        'তিনি কাছাকাছিই থাকেন।', 'এটা আমার কাছে আকর্ষণীয় মনে হচ্ছে।',
#        'আমি একটা খবরের কাগজ কিনলাম।', 'আমি অঙ্ক পছন্দ করি।',
#        'আমি তাকে দৌড়াতে দেখেছিলাম।',
#        'আমার মনে হয় আপনার আমার কোনো সাহায্য লাগবে না।',
#        'তোমার যে খাবার পছন্দ হয় সেটা খাও।', 'টম চেঁচানো বন্ধ করলো।',
#        'আমি আমার বেড়ালকে রোজ সকালে আর বিকালে খাবার দিই।',
#        'আপনি কি অনুগ্রহ করে এই ফর্মটি পূরণ করবেন', 'সবাই টমকে পছন্দ করত।',
#        'তুমি কি এই ছবির মধ্যের লোকটিকে দেখেছো',
#        'আপনি যেটা বললেন সেটা কি দয়া করে আর একবার বলতে পারবেন',
#        'আমি কি আমার মালপত্র এখানে রেখে যেতে পারি', 'টম শক্তিশালী।',
#        'টম কি জানে যে তুমি এখানে',
#        'এই বইটি সেই সমস্ত ছাত্রছাত্রীদের জন্য যাদের মাতৃভাষা জাপানী নয়।',
#        'আমি ওইগুলো নেবো।', 'টম টেনিস খেলতে পারে না।',
#        'আমার বাঁ কাঁধে একটা উল্কি আছে।', 'টম আহত হয়েছে।',
#        'টম ওটা নাও করতে চাইতে পারে।', 'টম জানে না যে মেরি এখানে।',
#        'আমি জানি টম তোমার বন্ধু ছিল।', 'উনি কে', 'আমি জানি টম ক্লান্ত।',
#        'আমি চাই আপনি টমের সঙ্গে থাকুন।', 'টমকে কে মেরেছে আমি জানি না।',
#        'আমি পরের বছর ফরাসি শিখবো।', 'আমি টিকিট কোথা থেকে কিনতে পারব',
#        'সে দৌড়ায়।', 'আমি তাঁদের দেখতে পেলাম।', 'নিজেকে সামলান।',
#        'তিনি এখনো আসেননি।', 'আমাকে চেড়ে দে।', 'দেখুন কে এসেছে।',
#        'আমি ওর নাম ভুলে গেছি।', 'টম চিৎকার করছে।', 'এখনো বৃষ্টি পরছে',
#        'উনি কাশলেন।', 'ঘুমাতে যাওয়ার আগে ওটা শেষ করে ফেলো।',
#        'আমাদের সাহায্য করো।', 'আমাকে ছেড়ে দাও।', 'কে এসেছিলো',
#        'টম বস্টনে থাকছে।', 'ডাক্তার ডাকো।', 'এই আসনটা কি নেওয়া হয়ে গেছে',
#        'একটু তারাতারি করুন।', 'আমি ওনাকে গাড়ি ধুতে দেখলাম।',
#        'আমার কফি খেতে ভালো লাগে না।', 'তোমরা কি মাংস খাও',
#        'তুমি ওখানে বসে আছো কেন', 'অনুগ্রহ করে নুনটা এগিয়ে দেবেন।',
#        'আমি এইটাই খুজছিলাম।', 'আমাদের সাহায্য করুন।', 'আমি ভালোই আছি।',
#        'সবাই কিছু না কিছু চায়।', 'আপনি কি পরের মাসে আমেরিকা যাবেন',
#        'টম এখনো এখানে এসে পৌছায়নি।', 'আপনি কি এই গানে নাচতে পারবেন',
#        'আমি অক্টোবরে জন্মেছি।', 'টম ওনার চোখ বন্ধ রেখেছিলেন।',
#        'সবাইকে সুপ্রভাত।', 'তাঁরা ঝগড়া করছিলেন।',
#        'আমার কিছু করার থাকলে জানাবেন।', 'আমি জানিনা আমার সময় আছে কি না।',
#        'তুমি কি এখন বুঝতে পারছো', 'ওরা শিশু।', 'শান্ত হও।', 'কোন মতেই না',
#        'টম ক্লান্ত।', 'আমার মা চটপটে।', 'তুমি ঠিক আছো', 'এটা বেশ চমৎকার।',
#        'অস্ট্রেলিয়া প্রাকৃতিক সম্পদে সমৃদ্ধ।',
#        'আমায় ক্ষমা কোর কিন্তু এটা সম্ভব নয়।', 'যাওয়া যাক',
#        'তুমি আমার নতুন গাড়িটা ব্যবহার করতে পারো।', 'ফরাসিতে এটাকে কী বলে',
#        'কাঁচটা কারুর দ্বারা ভাঙা হয়েছে।', 'টম অন্ধকারকে ভয় পায়।',
#        'আমি শুনলাম যে তাঁরা পার্ক স্ট্রিটের একটা বাড়ির ভিতের মধ্যে থেকে একটা কঙ্কাল পেয়েছেন।',
#        'কে', 'আপনি ক্লান্ত তাই না', 'তুমি ধনী।',
#        'টম একলা একলা ব্রেকফাস্ট খেলো।', 'আপনি কিসের ব্যাপারে কথা বলছেন',
#        'আপনি কখনো একা থাকবেন না।', 'সেইগুলো কি তোমার',
#        'দেখে মনে হচ্ছে আমার পৌছাত দেরি হয়ে যাবে।',
#        'টম আমাকে খুব ভালোভাবে চেনে।',
#        'আমি পুরোপুরি আমার পছন্দ মতো কোনো জুতো পেলাম না।',
#        'সবকিছুই এখানে আছে।', 'আপনি কেমন আছেন', 'টম কথা বলবে।',
#        'দ্বিতীয় বিশ্বযুদ্ধ ১৯৪৫ সালে সমাপ্ত হয়েছিল।', 'আমাকে চেড়ে দাও।',
#        'আমি তোমার থেকে অনেক কিছু শিখেছি।',
#        'আমার ইচ্ছা যে তুমি টমের সঙ্গে কথা বলো।',
#        'আমি দেখতে চাই টম কেমন ভাবে থাকে।', 'কেউ কথা বলছেন না।',
#        'আমাকে কি আসন সংরক্ষণ করতে হবে', 'লন্ডন ইংল্যান্ডের রাজধানি।',
#        'আমার ছোট ভাইটা টিভি দেখছে।', 'টম লড়াইটা শুরু করেছে।',
#        'টম আমাকে সারা দুপুর অপেক্ষা করিয়ে রেখেছিলেন।',
#        'আপনাকে ছাড়া এটা করতেই পারতাম না। ধন্যবাদ।', 'আমরা ভেতরে আছি।',
#        'আমার চাদরটা চাই।', 'ও বাচ্চাদের মত ঘুমাচ্ছে।',
#        'টম এখানে খুশি নয়।', 'কথা বলবেন না', 'টমকে জিজ্ঞাসা কর।',
#        'তুমি চিৎকার করছো কেন', 'আমি গ্রন্থাগারে।', 'তুমি ইংরাজি বলতে পার',
#        'তুমি কি কখনো টমকে ফরাসিতে কথা বলতে শুনেছো',
#        'আমাকে একলা টমের সঙ্গে দু মিনিট সময় দাও।',
#        'আমার নিয়ে চিন্তা করবেন না।', 'ভেতরে আসো।', 'আমি অসতর্ক ছিলাম।',
#        'তোমরা কি বোন', 'এতে আমি অবাক হইনি।', 'তোমরাই ভালো করে জানো।',
#        'ওটা একদম ভুলবে না।',
#        'গত সপ্তাহের শেষের দিকে উনি অসুস্থ হয়ে পরেছিলেন।',
#        'টম তারাতারি কথা বলে।', 'ওটা রাখুন।', 'উনি আসলে ম্যানেজারই নন।',
#        'ও হাঁটে।', 'আমি আপনাকে বিশ্বাস করি।', 'সেটার বয়স কত',
#        'টম এখনো গারদে।', 'তোমার হাতে সময় আছে',
#        'আপনি জানেন এই শব্দটির উচ্চারণ কিভাবে করতে হয়',
#        'আমি টিকিট কোথা থেকে কিনতে পারব', 'সবাই ওখানে আছেন।',
#        'ছুৃরিটা কোথায়', 'উনি সহজেই ওনার মাথা গরম করে ফেলেন।',
#        'আমি সহজেই ওনার বাড়ি খুজে পেয়েছিলাম।',
#        'মানুষরা অতিবেগুনী রশ্মিকে দেখতে পায় না।', 'আমি কৃতজ্ঞ থাকবো।',
#        'ওরা চিৎকার করলো।', 'টম তার মুখ উঁচু রাখার চেষ্টা করেছিল।',
#        'আমার এটা চাই।', 'ও একজন ডাক্তার।', 'টম কোথায় আছে খোঁজা যাক।',
#        'ও আমার থেকে ছোট।', 'রাষ্ট্রদূতটি ফিরে এসেছেন।',
#        'আমাকে অনুগ্রহ করে আপনার ফোন নাম্বারটি বলুন।', 'হতেই পারে না',
#        'ঠিক ওখানেই বসো।', 'আপনাদের যা কিছু পছন্দ হয় তাই খান।',
#        'তুই বড়ো হয়ে কী হতে চাস', 'তার জন্য খুব খারাপ লাগছে।',
#        'তিনি একজন ডাক্তার।', 'টমের উপর নজর রাখো।',
#        'আমি ভাবছিলাম তুমি এসে উপস্থিত হবে।',
#        'টম মেরির কাছ থেকে পরামর্শ চেয়েছিল।',
#        'আমাকে ব্যপারটা সামলাতে দাও।', 'টম কথা বলতে শুরু করলো',
#        'ওটা আমার সীট।', 'লাইব্রেরিটা বাঁদিকে।', 'টম চিৎকার করছে।',
#        'জিজ্ঞাসা করা যাক।', 'সঠিক জিনিসটা করা সবসময় অত সহজ হয় না।',
#        'মেরি কেকটা সাজালো।', 'তিন দিন পরে টমের ফাঁসি হবে।',
#        'সে পড়তে পারে।', 'ও আমাকে লিখতে শিখিয়েছে।', 'দয়া করে কিছু খান।',
#        'বসার জায়গা আছে', 'সে হাঁটে।', 'টম গান গাইতে চলেছে।',
#        'তুমি আমার মেয়ে।', 'আমরা খালি টমের সাথে কথা বলতে চাই।',
#        'সবাই এটা দেখেছিলো।', 'আপনার নাম কি',
#        'টম সাবধানে চারপাশে তাকিয়ে দেখল।', 'আপনারা কি ক্রেডিট কার্ড নেন',
#        'আমার মনে হয় না আমরা যথেষ্ট সময় পাবো।', 'টম ওটা করতে চায় না।',
#        'আমি সত্যিই দিশেহারা হয়ে পরেছি।',
#        'টম মিটিঙ্গের কথাটা প্রায় ভুলেই গেছিলো।',
#        'আমি এমন সব কাজ করেছি যাতে আমি গর্বিত নই।',
#        'আমরা অন্য কাউকে দোষারোপ করতে পারি না।', 'চুপ করো।', 'এটা আমার।',
#        'আমি আমার সব প্রতিবেশীকে চিনি।', 'সোমবার আপনি কোথায় যাচ্ছেন',
#        'টমের পিছু নিন।', 'আমি খুব একটা ধৈর্যশীল নই।',
#        'আমায় ক্ষমা করবেন কিন্তু এটা সম্ভব নয়।',
#        'আমি সত্যিই এখন খেতে চাই না।', 'আমি ওনার সাথে একমত নই।',
#        'টম গত অক্টোবর মারা গেছে।', 'আমিও ফরাসি শিখছি।',
#        'এর পরের স্টপ কোনটা', 'টমকে জিজ্ঞাসা করুন।',
#        'সবথেকে কাছের ডাকঘরে কিভাবে যাব', 'আমি এটা সামলে নিতে পারি।',
#        'নিজের দিকে ভালো করে খেয়াল রাখবেন।',
#        'আমি খাম কোথা থেকে কিনতে পারব', 'আমি স্বপ্ন দেখছিলাম।',
#        'এটা টমের গাড়ি।', 'আপনি বোঝেন না।', 'টম এখানে কাজ করতো।',
#        'চেখে দেখুন।', 'আমার গলাটা একটু শুকিয়ে গেছে।',
#        'এটা একেবারে অসম্ভব।', 'টম বই পড়তে ভালোবাসে।', 'এখন কয়টা বাজে',
#        'আপনি প্রথম মানুষ নন যে আমাকে এই কথাটা বলেছে।', 'ওনারা ডাক্তার।',
#        'গত সপ্তাহের শেষের দিকে ও অসুস্থ হয়ে পরেছিলো।', 'ও কে',
#        'টম বস্টনের কাছে একটা ছোট শহরে থাকে।', 'জোরে বলো',
#        'টম আপনাদের দেখলো।', 'এটা আমাকে অবাক করেনি।',
#        'সে বক্তৃতা দিচ্ছিলো।', 'টম ২০১৩ এ নির্বাচিত হয়েছিলো।',
#        'টমকে আমার থেকে দূরে রাখো।',
#        'আপনি কি আমাকে এই ঠিকানায় নিয়ে যেতে পারবেন',
#        'আমার পাসপোর্টের মেয়াদ শেষ হওয়ার আগে আমি আবার অস্ট্রেলিয়া যেতে চাই।',
#        'আপনি ইংরাজি পড়া কবে থেকে শুরু করলেন',
#        'টম যে ফাইলটা আপলোড করেছে আমি সেটা ডাউনলোড করলাম।',
#        'সে রেগে গেছিলো।',
#        'টমের বাবা মায়ের সঙ্গে আমাদের যোগাযোগ করা দরকার।',
#        'আকাশটা পরিষ্কার আছে।', 'তিনি ভালো মানুষ।', 'টম আহত হয়েছে।',
#        'আমার থেকে তোমার অবস্থা অনেক ভালো।',
#        'স্পষ্টতই টম কাউকেই আমাদের ব্যাপারে বলেনি।', 'কোনো অসুবিধা নেই।',
#        'ওনারা সবাই খুশি ছিলেন।', 'টম এখন বস্টনে থাকে।',
#        'তিনজন নিহত হয়েছেন।', 'আপনি কখনো ইউরোপে গেছেন',
#        'আপনিই টমের একমাত্র বন্ধু ছিলেন।',
#        'সোমবার অবধি অপেক্ষা করার কি আছে', 'ওটা কি এখানে আছে',
#        'টমকে পাওয়া গেছে।', 'আমি আমার ডান হাতটা মুড়তে পারছি না।',
#        'আমার রুম নম্বর কত', 'আমি আমার টুপিটি টমের গাড়িতে পেয়েছি।',
#        'তুমি কি বলছো আমি বুঝতে পারছি না।', 'টম আমাকে সেটা আজকে বললো।',
#        'ওনারা ডাক্তার।', 'টম তোর সাথে কথা বলতে চায়।',
#        'আমি টমকে আমার সাথে আসতে বললাম।', 'তুমি কখনো সেটা করেছো',
#        'টম একটা ডাইরি রাখার কথা ঠিক করেছেন।', 'তারা সবাই সুখী ছিলো।',
#        'আপনি কি ট্যাক্সি চালক', 'আমি চেষ্টা করিনি।', 'বাইরে খেলতে যাবেন',
#        'আপনি কত টাকা তুলতে চান', 'সেটা আমার জীবনের সব থেকে ভালো দিন ছিল।',
#        'আপনারা আগে যান।',
#        'উনি বাক্যাংশটির আক্ষরিক অর্থ ব্যাখ্যা করে দিলেন।',
#        'আমি কোনদিন কাউকে এই ব্যপারে বলিনি।', 'এ একজন ডাক্তার।',
#        'আমি ঠিক বুঝতে পরছি না।', 'আমার ইচ্ছা যে তুমি টমকে ডাকো।',
#        'টম তাকে দেখলো।', 'আমি হাসপাতালে গেছিলাম।',
#        'তিনি ফল ছাড়া আর কিছুই খান না।', 'আমাকে ডাকবেন না।',
#        'তোমারা কী করছো', 'টম মেরির পেছনে পেছনে বাড়ির বাইরে গেল।',
#        'সকালের খাওয়াটা কখন দেওয়া হয়', 'তোমরা চিৎকার করছো কেন',
#        'আজ রাষ্ট্রীয় ছুটির দিন।', 'আমরা আজ বাড়িতেই থাকব।',
#        'সে ফরাসিতে কথা বলে।', 'এটা এখনও আমার।', 'ওই কেকটা সুস্বাদু ছিলো।',
#        'বাইরে এতই গরম যে আমি পুরোদিন আমার শীততাপ নিয়ন্ত্রিত বাড়িতে থাকতে চাই।',
#        'আমি ওনাদের দেখতে পেলাম।', 'আজ গরম আছে।', 'ওখানে কেউ থাকে না।',
#        'তুমি বস্টনে কত বছর ধরে আছো', 'আমাকে কথা বলতে দাও।',
#        'আমি এখনো তোমার বন্ধু আছি।', 'এই দাঁতটা ব্যথা করছে।',
#        'ও কী করে না করে আমরা তা কেয়ার করি না।',
#        'টম এক মিনিট ধরে তার নিশ্বাস আটকে রাখলো।', 'কিছু খেয়ে নিন।',
#        'আর কিছু', 'আমি বাইরে ছিলাম।', 'কী হয়েছে', 'এটা বেশ ভালো।',
#        'তোমরা কি আমাদের সাথে মাছ ধরতে যাবে', 'তোমরা চেঁচাচ্ছো কেন',
#        'তাহলে আবার কী', 'আমি ওনার আমন্ত্রণ গ্রহণ করলাম।',
#        'ওরা ঝগড়া করছিল।', 'এটা কি তোমার বই', 'আমি নশ্চিত নই।',
#        'আমার ডান পা ব্যাথা করছে।', 'তাই বুঝি', 'টম চেঁচালো।',
#        'কোনো একদিন আমি হাওয়ার মত দৌড়াবো।', 'টম ভুরু কোঁচকালো।',
#        'তুমি কটার সময় ঘুমাতে যাও', 'আমি তার আমন্ত্রণ গ্রহণ করলাম।',
#        'এটা আমার ব্যাগ।', 'কী হোল', 'তোমরা যত ইচ্ছে তত খেতে পারো।',
#        'টম আহত হয়েছে।', 'আমি টম।', 'টম ওটা দেখেছে।',
#        'আমি এখনো আমার কন্ট্যাক্ট লেন্সটি পাইনি।',
#        'টম চেঁচাতে আরম্ভ করলো।', 'এই নিন আপনার মগ।',
#        'যোগাযোগ বিচ্ছিন্ন হলো।', 'উনি কি আমেরিকান', 'আমি ওতে গর্বিত নই।',
#        'এখনকার সময় শুধু বেঁচে থাকাটাও যথেষ্ট কঠিন।',
#        'টম চোরটাকে ধরে ফেললো।', 'বাচ্চারা কেক পছন্দ করে।',
#        'কেউই ফোনটার জবাব দিলো না।',
#        'আমার আগে টমের সঙ্গে কথা বলা উচিৎ ছিল।', 'টম প্রচুর কাজ করে।',
#        'টম কী নিয়ে আসবে', 'টম এখানে থাকতে চায় না।',
#        'আমি এক জোড়া জুতো কিনলাম।', 'আমাদের ডাকবেন।',
#        'টম চিৎকার করতে শুরু করলো।', 'আমি এটা অস্বীকার করছি না।',
#        'তাদের বাবামায়েরা তাদেরকে দূরে রাখতে চেষ্টা করেছিলেন।',
#        'ট্রেনটা সব স্টেশনে থামে।', 'আস্তে হাঁটো।',
#        'ওর এক তিক্ত অভিজ্ঞতা হয়েছিলো।', 'টম খুব তারাতারি খায়।',
#        'আমি কি ঠিক দিকেই যাচ্ছি',
#        'আমি নদীটা সাঁতরে পার হওয়ার চেষ্টা করলাম।',
#        'আমি সহজেই তাঁর বাড়ি খুজে পেয়েছিলাম।', 'কেউ আছেন',
#        'আমি উত্তরটা জানিনা।', 'আমার মালপত্রটা একটু দেখবেন',
#        'আমি কাছাকাছিই থাকবো।',
#        'অনিচ্ছা সত্বেও টম দাঁতের ডাক্তারের কাছে গেলো।',
#        'ও ফ্রান্সে বড়ো হয়েছে।', 'টম খুব মন দিয়ে শুনছে বলে মনে হচ্ছে।',
#        'তোমার বয়স কত', 'সে বললো।', 'আমার ১৯ বছর বয়স।'], dtype='<U96')

# %%
pred_df.sample(100)
# Out:
#                                     actual  \
# 688                        that is my seat
# 75                           tom got angry
# 743  tom lives in a small town near boston
# 785       that was the best day of my life
# 289          my father can fly an airplane
# ..                                     ...
# 335                               stop tom
# 557                                he runs
# 356               i was at a movie theater
# 269               im not very good at this
# 176                      why cant you come
#
#                                     actual2  \
# 688                           ওটা আমার সীট।
# 75                          টম রেগে গেছিলো।
# 743     টম বস্টনের কাছে একটা ছোট শহরে থাকে।
# 785  সেটা আমার জীবনের সব থেকে ভালো দিন ছিল।
# 289             আমার বাবা প্লেন ওড়াতে পারে।
# ..                                      ...
# 335                             টমকে আটকান।
# 557                               সে দৌড়ায়।
# 356              আমি একটা সিনেমা হলে ছিলাম।
# 269               আমি এতে খুব একটা ভালো নই।
# 176                 তোমরা আসতে পারবে না কেন
#
#                                          predicted
# 688                          এটা কি তোমার বোন।
# 75                            টম রেগে গেছিলো।
# 743       টম আঠারো অবস্থায় ছিলো তখন জন্য গ্রেফতার
# 785  আপনি কখন ফিরবেন সবকিছুই আবহাওয়ার উপর নির্ভর
# 289               আমার ছেলে আমার ঘরে কাটতে পারে।
# ..                                             ...
# 335                              টমকে থামান।
# 557                               ইনি দৌড়ান।
# 356             আমি এখনো ফাইলটা নামাইনি। করিনি।
# 269             আমি এই ব্যাপারে খুব একটা ভালো নই।
# 176                     আপনি আসতে পারবেন না কেন
#
# [100 rows x 3 columns]
